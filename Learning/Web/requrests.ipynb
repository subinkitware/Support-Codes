# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
r
# Out:
# <Response [200]>

# %%
r = requests.post('https://httpbin.org/post', data={'key': 'value'})
r
# Out:
# <Response [200]>

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://api.github.com/events', params=payload)
print(r.url)
# Out:
# https://api.github.com/events?key1=value1&key2=value2

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('https://api.github.com/events', params=payload)
print(r.url)
# Out:
# https://api.github.com/events?key1=value1&key2=value2&key2=value3

# %%
r = requests.get('https://api.github.com/events')
dir(r)
print(r.text)
print(r.encoding)
# Out:
# [{"id":"33586619136","type":"PushEvent","actor":{"id":54129,"login":"maxandersen","display_login":"maxandersen","gravatar_id":"","url":"https://api.github.com/users/maxandersen","avatar_url":"https://avatars.githubusercontent.com/u/54129?"},"repo":{"id":689061477,"name":"jbangdev/jbang-python","url":"https://api.github.com/repos/jbangdev/jbang-python"},"payload":{"repository_id":689061477,"push_id":15946547563,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"285df32dcbcbdb93e9b5d1936424dc45e81f44b4","before":"67bdc0fcf8c70ab5d1f834168f35dcae7f1e6121","commits":[{"sha":"285df32dcbcbdb93e9b5d1936424dc45e81f44b4","author":{"email":"max@xam.dk","name":"Max Rydahl Andersen"},"message":"bump version","distinct":true,"url":"https://api.github.com/repos/jbangdev/jbang-python/commits/285df32dcbcbdb93e9b5d1936424dc45e81f44b4"}]},"public":true,"created_at":"2023-11-24T00:35:52Z","org":{"id":60074102,"login":"jbangdev","gravatar_id":"","url":"https://api.github.com/orgs/jbangdev","avatar_url":"https://avatars.githubusercontent.com/u/60074102?"}},{"id":"33586619127","type":"WatchEvent","actor":{"id":150805405,"login":"yuralove","display_login":"yuralove","gravatar_id":"","url":"https://api.github.com/users/yuralove","avatar_url":"https://avatars.githubusercontent.com/u/150805405?"},"repo":{"id":123458551,"name":"jackfrued/Python-100-Days","url":"https://api.github.com/repos/jackfrued/Python-100-Days"},"payload":{"action":"started"},"public":true,"created_at":"2023-11-24T00:35:52Z"},{"id":"33586619107","type":"PushEvent","actor":{"id":111329684,"login":"B74LABgit","display_login":"B74LABgit","gravatar_id":"","url":"https://api.github.com/users/B74LABgit","avatar_url":"https://avatars.githubusercontent.com/u/111329684?"},"repo":{"id":706371936,"name":"B74LABgit/CAM","url":"https://api.github.com/repos/B74LABgit/CAM"},"payload":{"repository_id":706371936,"push_id":15946547562,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"f121add4dbb5d8ed467e88ce2ee155f2a1e1fa06","before":"ebe7b7a5f0fb362230c29c6cb5c588fee5c4acb5","commits":[{"sha":"f121add4dbb5d8ed467e88ce2ee155f2a1e1fa06","author":{"email":"111329684+B74LABgit@users.noreply.github.com","name":"B74LABgit"},"message":"committing files","distinct":true,"url":"https://api.github.com/repos/B74LABgit/CAM/commits/f121add4dbb5d8ed467e88ce2ee155f2a1e1fa06"}]},"public":true,"created_at":"2023-11-24T00:35:52Z"},{"id":"33586619131","type":"PushEvent","actor":{"id":140261155,"login":"LeonardoHSSoares","display_login":"LeonardoHSSoares","gravatar_id":"","url":"https://api.github.com/users/LeonardoHSSoares","avatar_url":"https://avatars.githubusercontent.com/u/140261155?"},"repo":{"id":710084948,"name":"LeonardoHSSoares/PortugolStudio-pseudoCode","url":"https://api.github.com/repos/LeonardoHSSoares/PortugolStudio-pseudoCode"},"payload":{"repository_id":710084948,"push_id":15946547574,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"6d5bcb0b4a34a41fc2ca50de78306f167956661e","before":"7ce1d7df3325cd7d0c2433886fa7de17a8ec79d3","commits":[{"sha":"6d5bcb0b4a34a41fc2ca50de78306f167956661e","author":{"email":"mascoty2005@gmail.com","name":"Leonardo Soares"},"message":"refactor: Modulação","distinct":true,"url":"https://api.github.com/repos/LeonardoHSSoares/PortugolStudio-pseudoCode/commits/6d5bcb0b4a34a41fc2ca50de78306f167956661e"}]},"public":true,"created_at":"2023-11-24T00:35:52Z"},{"id":"33586619110","type":"IssueCommentEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":681905603,"name":"fwfurtado/Gatekeeper","url":"https://api.github.com/repos/fwfurtado/Gatekeeper"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/fwfurtado/Gatekeeper/issues/48","repository_url":"https://api.github.com/repos/fwfurtado/Gatekeeper","labels_url":"https://api.github.com/repos/fwfurtado/Gateke ...
# utf-8

# %%
print(r.json())
# Out:
# [{'id': '33586619136', 'type': 'PushEvent', 'actor': {'id': 54129, 'login': 'maxandersen', 'display_login': 'maxandersen', 'gravatar_id': '', 'url': 'https://api.github.com/users/maxandersen', 'avatar_url': 'https://avatars.githubusercontent.com/u/54129?'}, 'repo': {'id': 689061477, 'name': 'jbangdev/jbang-python', 'url': 'https://api.github.com/repos/jbangdev/jbang-python'}, 'payload': {'repository_id': 689061477, 'push_id': 15946547563, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '285df32dcbcbdb93e9b5d1936424dc45e81f44b4', 'before': '67bdc0fcf8c70ab5d1f834168f35dcae7f1e6121', 'commits': [{'sha': '285df32dcbcbdb93e9b5d1936424dc45e81f44b4', 'author': {'email': 'max@xam.dk', 'name': 'Max Rydahl Andersen'}, 'message': 'bump version', 'distinct': True, 'url': 'https://api.github.com/repos/jbangdev/jbang-python/commits/285df32dcbcbdb93e9b5d1936424dc45e81f44b4'}]}, 'public': True, 'created_at': '2023-11-24T00:35:52Z', 'org': {'id': 60074102, 'login': 'jbangdev', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/jbangdev', 'avatar_url': 'https://avatars.githubusercontent.com/u/60074102?'}}, {'id': '33586619127', 'type': 'WatchEvent', 'actor': {'id': 150805405, 'login': 'yuralove', 'display_login': 'yuralove', 'gravatar_id': '', 'url': 'https://api.github.com/users/yuralove', 'avatar_url': 'https://avatars.githubusercontent.com/u/150805405?'}, 'repo': {'id': 123458551, 'name': 'jackfrued/Python-100-Days', 'url': 'https://api.github.com/repos/jackfrued/Python-100-Days'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2023-11-24T00:35:52Z'}, {'id': '33586619107', 'type': 'PushEvent', 'actor': {'id': 111329684, 'login': 'B74LABgit', 'display_login': 'B74LABgit', 'gravatar_id': '', 'url': 'https://api.github.com/users/B74LABgit', 'avatar_url': 'https://avatars.githubusercontent.com/u/111329684?'}, 'repo': {'id': 706371936, 'name': 'B74LABgit/CAM', 'url': 'https://api.github.com/repos/B74LABgit/CAM'}, 'payload': {'repository_id': 706371936, 'push_id': 15946547562, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'f121add4dbb5d8ed467e88ce2ee155f2a1e1fa06', 'before': 'ebe7b7a5f0fb362230c29c6cb5c588fee5c4acb5', 'commits': [{'sha': 'f121add4dbb5d8ed467e88ce2ee155f2a1e1fa06', 'author': {'email': '111329684+B74LABgit@users.noreply.github.com', 'name': 'B74LABgit'}, 'message': 'committing files', 'distinct': True, 'url': 'https://api.github.com/repos/B74LABgit/CAM/commits/f121add4dbb5d8ed467e88ce2ee155f2a1e1fa06'}]}, 'public': True, 'created_at': '2023-11-24T00:35:52Z'}, {'id': '33586619131', 'type': 'PushEvent', 'actor': {'id': 140261155, 'login': 'LeonardoHSSoares', 'display_login': 'LeonardoHSSoares', 'gravatar_id': '', 'url': 'https://api.github.com/users/LeonardoHSSoares', 'avatar_url': 'https://avatars.githubusercontent.com/u/140261155?'}, 'repo': {'id': 710084948, 'name': 'LeonardoHSSoares/PortugolStudio-pseudoCode', 'url': 'https://api.github.com/repos/LeonardoHSSoares/PortugolStudio-pseudoCode'}, 'payload': {'repository_id': 710084948, 'push_id': 15946547574, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '6d5bcb0b4a34a41fc2ca50de78306f167956661e', 'before': '7ce1d7df3325cd7d0c2433886fa7de17a8ec79d3', 'commits': [{'sha': '6d5bcb0b4a34a41fc2ca50de78306f167956661e', 'author': {'email': 'mascoty2005@gmail.com', 'name': 'Leonardo Soares'}, 'message': 'refactor: Modulação', 'distinct': True, 'url': 'https://api.github.com/repos/LeonardoHSSoares/PortugolStudio-pseudoCode/commits/6d5bcb0b4a34a41fc2ca50de78306f167956661e'}]}, 'public': True, 'created_at': '2023-11-24T00:35:52Z'}, {'id': '33586619110', 'type': 'IssueCommentEvent', 'actor': {'id': 49699333, 'login': 'dependabot[bot]', 'display_login': 'dependabot', 'gravatar_id': '', 'url': 'https://api.github.com/users/dependabot[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'}, 'repo': {'id': 681905603, 'name': 'fwfurtado/Gatekeeper', 'url': 'https://api.github.com/repos/fwfurtado/Gatekeeper'} ...

# %%
# custom headers
url = 'https://api.github.com/some/endpoint'
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get(url, headers=headers)
r.text
# Out:
# '{"message":"Not Found","documentation_url":"https://docs.github.com/rest"}'

# %%
url = 'https://httpbin.org/post'
files = {'file': open('report.xls', 'rb')}

r = requests.post(url, files=files)
r.headers
# Out:
# {'Date': 'Fri, 24 Nov 2023 01:03:09 GMT', 'Content-Type': 'application/json', 'Content-Length': '510', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
